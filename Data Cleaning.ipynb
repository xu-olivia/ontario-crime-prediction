# %% [markdown]
# ## Step1: Clean the demographic data

# %%
import pandas as pd

# Load population, education & income data
demographic = pd.read_excel('/Users/Olivia/Desktop/Ontario Open Data Crime Statistics.xlsx', sheet_name='population_education_income')

demographic.head()
# Out:
#                                            Geography postalcode  \
# 0        Brant County Health Unit, Ontario [3527-A]    N3R 1G7
# 1        Chatham-Kent Health Unit, Ontario [3540-E]    N7M 5L8
# 2    City of Hamilton Health Unit, Ontario [3537-A]    L8P 4S6
# 3     City of Toronto Health Unit, Ontario [3595-G]     M5B 1W2
# 4  District of Algoma Health Unit, Ontario [3526-E]     P6B 0A8
#
#    Census families in private households  Female lone-parent families  \
# 0                                39470.0                         5965
# 1                                30415.0                         3985
# 2                               144120.0                        21925
# 3                               690340.0                       123530
# 4                                34300.0                         4650
#
#    Female lone-parent families, proportion of census families (percent)  \
# 0                                               15.1
# 1                                               13.1
# 2                                               15.2
# 3                                               17.9
# 4                                               13.6
#
#    Lone-parent families  \
# 0                  7450
# 1                  5055
# 2                 27220
# 3                146990
# 4                  5955
#
#    Lone-parent families, proportion of census families (percent)  \
# 0                                               18.9
# 1                                               16.6
# 2                                               18.9
# 3                                               21.3
# 4                                               17.4
#
#    Male lone-parent families  \
# 0                       1485
# 1                       1070
# 2                       5290
# 3                      23455
# 4                       1305
#
#    Male lone-parent families, proportion of census families (percent)  \
# 0                                                3.8
# 1                                                3.5
# 2                                                3.7
# 3                                                3.4
# 4                                                3.8
#
#    Total population  ...  Post-secondary graduates aged 25 to 54  \
# 0            137100  ...                                   32250
# 1            104075  ...                                   20620
# 2            519950  ...                                  135625
# 3           2615060  ...                                  849145
# 4            114785  ...                                   26215
#
#    Post-secondary graduates aged 25 to 54, proportion of population aged 25 to 54 (percent)  \
# 0                                               59.1
# 1                                               52.2
# 2                                               63.9
# 3                                               71.2
# 4                                               61.7
#
#    Prevalence of low income before tax in 2010 for economic families for income status (percent)  \
# 0                                                8.2
# 1                                               10.8
# 2                                               14.0
# 3                                               18.9
# 4                                                8.4
#
#    Prevalence of persons aged 17 years and under living in low income economic families before tax in 2010 (percent)  \
# 0                                               12.9
# 1                                               18.2
# 2                                               22.6
# 3                                               28.4
# 4                                               14.9
#
#    Total economic families for income status  \
# 0                                      36745
# 1                                      30130
# 2                                     141850
# 3                                     675900
# 4                                      33280
#
#    Total persons aged 17 years and under living in economic families  \
# 0                                              30820
# 1                                              21650
# 2                                             105955
# 3                                             486400
# 4                                              20370
#
#    Total population in private households  \
# 0                                  134850
# 1                                  102075
# 2                                  509640
# 3                                 2576025
# 4                                  112750
#
#    Unemployment rate 15 years and over (percent)  Visible minority population  \
# 0                                            7.6                         7490
# 1                                           10.2                         4015
# 2                                            8.7                        79970
# 3                                            9.3                      1264390
# 4                                           10.9                         1695
#
#    Visible minority population, proportion of total population (percent)
# 0                                                5.6
# 1                                                3.9
# 2                                               15.7
# 3                                               49.1
# 4                                                1.5
#
# [5 rows x 36 columns]

# %%
# Check the data type of individual columns, see if modification is required
demographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 36 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   Geography                                                                                                          35 non-null     object
#  1   postalcode                                                                                                         35 non-null     object
#  2   Census families in private households                                                                              34 non-null     float64
#  3   Female lone-parent families                                                                                        35 non-null     int64
#  4   Female lone-parent families, proportion of census families (percent)                                               35 non-null     float64
#  5   Lone-parent families                                                                                               35 non-null     int64
#  6   Lone-parent families, proportion of census families (percent)                                                      35 non-null     float64
#  7   Male lone-parent families                                                                                          35 non-null     int64
#  8   Male lone-parent families, proportion of census families (percent)                                                 35 non-null     float64
#  9   Total population                                                                                                   35 non-null     int64
#  10  Average total income in 2010 of population 15 years and over (canadian dollars)                                    35 non-null     int64
#  11  Economic families in low income before tax in 2010 for income status                                               35 non-null     int64
#  12  Employed persons aged 25 to 54 years                                                                               35 non-null     int64
#  13  Employment rate, 25-54 years (percent)                                                                             35 non-null     float64
#  14  High school graduates aged 25 to 29                                                                                35 non-null     int64
#  15  High school graduates aged 25 to 29, proportion of population aged 25 to 29 (percent)                              35 non-null     float64
#  16  Immigrant population                                                                                               35 non-null     int64
#  17  Immigrant population, proportion of total population (percent)                                                     35 non-null     float64
#  18  Immigrants who arrived between 2001 and 2011                                                                       35 non-null     int64
#  19  Immigrants who arrived between 2001 and 2011, proportion of immigrant population (percent)                         35 non-null     float64
#  20  Immigrants who arrived between 2001 and 2011, proportion of total population (percent)                             35 non-null     float64
#  21  Labour force aged 15 and over                                                                                      35 non-null     int64
#  22  Long-term unemployed                                                                                               35 non-null     int64
#  23  Long-term unemployment rate, labour force aged 15 and over (percent)                                               35 non-null     float64
#  24  Persons aged 17 years and under living in low income economic families before tax in 2010                          35 non-null     int64
#  25  Population aged 25 to 29                                                                                           35 non-null     int64
#  26  Post-secondary graduates aged 25 to 54                                                                             35 non-null     int64
#  27  Post-secondary graduates aged 25 to 54, proportion of population aged 25 to 54 (percent)                           35 non-null     float64
#  28  Prevalence of low income before tax in 2010 for economic families for income status (percent)                      35 non-null     float64
#  29  Prevalence of persons aged 17 years and under living in low income economic families before tax in 2010 (percent)  35 non-null     float64
#  30  Total economic families for income status                                                                          35 non-null     int64
#  31  Total persons aged 17 years and under living in economic families                                                  35 non-null     int64
#  32  Total population in private households                                                                             35 non-null     int64
#  33  Unemployment rate 15 years and over (percent)                                                                      35 non-null     float64
#  34  Visible minority population                                                                                        35 non-null     int64
#  35  Visible minority population, proportion of total population (percent)                                              35 non-null     float64
# dtypes: float64(15), int64(19), object(2)
# memory usage: 10.0+ KB

# %%
# Check for missing values

# Find columns with null values
null_counts = demographic.isnull().sum()

# If a column contains null value(s), print the number of null values
for column, count in null_counts.items():
    if count > 0:
        print(f"Column '{column}' has {count} null values.")
# Out:
# Column 'Census families in private households' has 1 null values.

# %%
# Impute the missing values

# Calculate the percentage of 'Census families in private households' in 'Total Population'
demographic['Ratio'] = demographic['Census families in private households'] / demographic['Total population']

# Calculate the average percentage
average_ratio = demographic['Ratio'].mean()

# 3.Muptiple the 'Census families in private households' by the average percentage. Fill the empty cell with the estimated value
demographic['Census families in private households'].fillna((demographic['Total population'] * average_ratio).astype(int), inplace=True)

# %%
# Check for duplicate rows. If there are any duplicates, remove them.

# Detect duplicate rows
duplicates = demographic[demographic.duplicated(keep=False)]  

# Print duplicate rows
if not duplicates.empty:
    print("Duplicate Rows:")
    print(duplicates)
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
# Define a function to shorten the column
def clean_region_name(record):
    return record.split(', Ontario')[0]

# Apply the function to the 'Geography' column 
demographic['Geography'] = demographic['Geography'].apply(clean_region_name)

# Display the updated column
demographic['Geography'].head()
# Out:
# 0          Brant County Health Unit
# 1          Chatham-Kent Health Unit
# 2      City of Hamilton Health Unit
# 3       City of Toronto Health Unit
# 4    District of Algoma Health Unit
# Name: Geography, dtype: object

# %%
# Drop the unecessary column
demographic = demographic.drop(columns=['Ratio'])

# Save the cleaned data to an Excel file
excel_file_path = '/Users/Olivia/Desktop/Demographic_Cleaned.xlsx'
demographic.to_excel(excel_file_path, sheet_name='Demographic Cleaned')

# %% [markdown]
# ## Step 2: Clean the crime data

# %%
# Load the crime data

crime = pd.read_excel('/Users/Olivia/Desktop/Ontario Open Data Crime Statistics.xlsx', sheet_name='Criminal_Offences')

crime.head()
# Out:
#    Record ID                                     Link Geography  \
# 0          1  Simcoe Muskoka District Health Unit, Ontario [...
# 1          2  Simcoe Muskoka District Health Unit, Ontario [...
# 2          3  Simcoe Muskoka District Health Unit, Ontario [...
# 3          4  Simcoe Muskoka District Health Unit, Ontario [...
# 4          5  Simcoe Muskoka District Health Unit, Ontario [...
#
#   Census_Divison              OFFENCE GROUP           OFFENCE TYPE  \
# 0         Barrie  Crimes Against the Person               Homicide
# 1         Barrie  Crimes Against the Person       Attempted Murder
# 2         Barrie  Crimes Against the Person                Robbery
# 3         Barrie  Crimes Against the Person         Sexual Assault
# 4         Barrie  Crimes Against the Person  Other Sexual Offences
#
#    Cases Received % of All Cases Received  Cases Disposed  \
# 0               0                    0.0%               2
# 1               6                    0.8%               3
# 2              19                    2.6%              10
# 3               7                    0.9%               9
# 4               9                    1.2%               5
#
#    Avg Days to Disposition\n(for cases without bench warrants)  \
# 0                                              325.0
# 1                                               62.0
# 2                                              194.0
# 3                                              313.0
# 4                                              271.0
#
#    Avg Appearances to Disposition\n(for cases without bench warrants)  ...  \
# 0                                               16.5                   ...
# 1                                                7.0                   ...
# 2                                                8.1                   ...
# 3                                               13.8                   ...
# 4                                                4.6                   ...
#
#    Cases Disposed Before Trial Date TOTAL  \
# 0                                       0
# 1                                       3
# 2                                       8
# 3                                       8
# 4                                       3
#
#    Cases Disposed Before Trial Date Withdrawn/ Stayed Before Trial  \
# 0                                                  0
# 1                                                  3
# 2                                                  4
# 3                                                  1
# 4                                                  2
#
#    Cases Disposed Before Trial Date Guilty Plea Before Trial  \
# 0                                                  0
# 1                                                  0
# 2                                                  4
# 3                                                  7
# 4                                                  0
#
#    Cases Disposed Before Trial Date Other Disposition Before Trial  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Cases Disposed at Trial Without Trial TOTAL  \
# 0                                            0
# 1                                            0
# 2                                            2
# 3                                            1
# 4                                            2
#
#    Cases Disposed at Trial Without Trial Withdrawn at Trial  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  2
#
#    Cases Disposed at Trial Without Trial Guilty Plea at Trial  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Cases Disposed at Trial Without Trial Other Disposition at Trial  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Cases Disposed Following a Trial TOTAL  Trial Rate
# 0                                       2      100.0%
# 1                                       0        0.0%
# 2                                       0        0.0%
# 3                                       0        0.0%
# 4                                       0        0.0%
#
# [5 rows x 21 columns]

# %%
# Check the data type of individual columns, see if modification is required
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Data columns (total 21 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Record ID                                                          1674 non-null   int64
#  1   Link Geography                                                     1674 non-null   object
#  2   Census_Divison                                                     1674 non-null   object
#  3   OFFENCE GROUP                                                      1674 non-null   object
#  4   OFFENCE TYPE                                                       1674 non-null   object
#  5   Cases Received                                                     1674 non-null   int64
#  6   % of All Cases Received                                            1674 non-null   object
#  7   Cases Disposed                                                     1674 non-null   int64
#  8   Avg Days to Disposition
# (for cases without bench warrants)         1170 non-null   float64
#  9   Avg Appearances to Disposition
# (for cases without bench warrants)  1170 non-null   float64
#  10  Cases Pending                                                      1674 non-null   int64
#  11  Cases Disposed Before Trial Date TOTAL                             1674 non-null   int64
#  12  Cases Disposed Before Trial Date Withdrawn/ Stayed Before Trial    1674 non-null   int64
#  13  Cases Disposed Before Trial Date Guilty Plea Before Trial          1674 non-null   int64
#  14  Cases Disposed Before Trial Date Other Disposition Before Trial    1674 non-null   int64
#  15  Cases Disposed at Trial Without Trial TOTAL                        1674 non-null   int64
#  16  Cases Disposed at Trial Without Trial Withdrawn at Trial           1674 non-null   int64
#  17  Cases Disposed at Trial Without Trial Guilty Plea at Trial         1674 non-null   int64
#  18  Cases Disposed at Trial Without Trial Other Disposition at Trial   1674 non-null   int64
#  19  Cases Disposed Following a Trial TOTAL                             1674 non-null   int64
#  20  Trial Rate                                                         1198 non-null   object
# dtypes: float64(2), int64(13), object(6)
# memory usage: 274.8+ KB

# %%
# Change the data type of selected column from object to numerical

crime['Trial Rate'] = pd.to_numeric(crime['Trial Rate'], errors ='coerce')
crime['% of All Cases Received'] = pd.to_numeric(crime['% of All Cases Received'], errors='coerce')

# %%
# Fill missing values with 0
crime_numeric = crime.select_dtypes(include=['float64', 'int64']).fillna(0)
crime.update(crime_numeric)

# Verify that there are no missing values left
print(crime.isna().sum())
# Out:
# Record ID                                                             0
# Link Geography                                                        0
# Census_Divison                                                        0
# OFFENCE GROUP                                                         0
# OFFENCE TYPE                                                          0
# Cases Received                                                        0
# % of All Cases Received                                               0
# Cases Disposed                                                        0
# Avg Days to Disposition\n(for cases without bench warrants)           0
# Avg Appearances to Disposition\n(for cases without bench warrants)    0
# Cases Pending                                                         0
# Cases Disposed Before Trial Date TOTAL                                0
# Cases Disposed Before Trial Date Withdrawn/ Stayed Before Trial       0
# Cases Disposed Before Trial Date Guilty Plea Before Trial             0
# Cases Disposed Before Trial Date Other Disposition Before Trial       0
# Cases Disposed at Trial Without Trial TOTAL                           0
# Cases Disposed at Trial Without Trial Withdrawn at Trial              0
# Cases Disposed at Trial Without Trial Guilty Plea at Trial            0
# Cases Disposed at Trial Without Trial Other Disposition at Trial      0
# Cases Disposed Following a Trial TOTAL                                0
# Trial Rate                                                            0
# dtype: int64

# %%
# Resolve the discrepencies in 'Link Geography' column, transform all records into the same format

def remove_after_ontario(record):
    return record.split(', Ontario')[0]

# Apply the function to the 'Link Geography' column
crime['Link Geography'] = crime['Link Geography'].apply(remove_after_ontario)

# Display the updated column
crime['Link Geography'].head()
# Out:
# 0    Simcoe Muskoka District Health Unit
# 1    Simcoe Muskoka District Health Unit
# 2    Simcoe Muskoka District Health Unit
# 3    Simcoe Muskoka District Health Unit
# 4    Simcoe Muskoka District Health Unit
# Name: Link Geography, dtype: object

# %%
# Change the variants to the same naming convention
crime['OFFENCE GROUP'] = crime['OFFENCE GROUP'].replace('Admin of Justice', 'Administration of Justice')

# Verify the changes by printing unique values in the 'Offense Group' column
print(crime['OFFENCE GROUP'].unique())
# Out:
# ['Crimes Against the Person' 'Crimes Against Property'
#  'Administration of Justice' 'Other Criminal Code' 'Criminal Code Traffic'
#  'Federal Statute']

# %%
# Save the cleaned data to an Excel file
excel_file_path = '/Users/Olivia/Desktop/Criminal Offenses_Cleaned.xlsx'
crime.to_excel(excel_file_path, sheet_name='Criminal Offenses Cleaned')
